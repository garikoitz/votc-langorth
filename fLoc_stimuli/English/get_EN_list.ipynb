# %%
import pandas as pd
en_list=pd.read_csv('/Users/tiger/toolboxes/votc-langorth/DATA/English_high_frequency_final.txt',sep='\t',encoding="utf-16")

# %%
en_list
# Out:
#      word|s  conc|f  fre|f  l|f   bigr|f       neig|f
# 0      able     302    216    4       8.02          3
# 1    advice     291     51    6      13.53          1
# 2    afraid     336     57    6      12.02          0
# 3    agency     426     56    6      11.84          0
# 4     allow     268     72    5       9.81          3
# ..      ...     ...    ...  ...        ...        ...
# 550   write     446    106    5      12.32          4
# 551   wrong     303    129    5      12.79          3
# 552   wrote     385    181    5      11.80          1
# 553  yellow     537     55    6      13.05          3
# 554   youth     439     82    5      12.68          2
#
# [555 rows x 6 columns]

# %%
en_list=en_list['word|s']

# %%
en_list.to_csv('/Users/tiger/Desktop/EN_RWH.txt',index=False)
