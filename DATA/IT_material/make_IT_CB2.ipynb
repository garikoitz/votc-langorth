# %%
# read the highlow word list, delete things from IT_RW.txt, have a new list
import os
import pandas as pd

# %%
base_dir='/Users/tiger/toolboxes/votc-langorth/DATA/IT_material'

ref_txt=os.path.join(base_dir, 'IT_RW.txt')

src_txt= os.path.join(base_dir,'IT_RW_list_wuggy_filtered.txt')

output_txt= os.path.join(base_dir, 'IT_RW_wuggy_filtered_rest.txt')

# %%
ref=pd.read_csv(ref_txt, header=0)

src=pd.read_csv(src_txt, header=0)

# %%
ref=ref.squeeze()

# %%
condition=~src['LEMMA'].isin(ref)

# %%
condition
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 4653    True
# 4654    True
# 4655    True
# 4656    True
# 4657    True
# Name: LEMMA, Length: 4658, dtype: bool

# %%
targ=src[condition]

# %%
targ.iloc[:,1:3].to_csv(output_txt,header=0, index=False)

# %%
# now filter the IT_RW_CB2.txt for the following processing

CB2_path=os.path.join(base_dir, 'IT_RW_CB2.txt')

cb2=pd.read_csv(CB2_path, header=None)

# %%
cb2=cb2.iloc[:,0]

# %%
cb2.to_csv(CB2_path,header=None, index=False)
